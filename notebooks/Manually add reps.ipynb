# %%
import pickle
import pandas

# %%
with open('all_samples.p') as sample_file:
    data=pickle.load(sample_file)

# %%
#Code here to add reps
df=pandas.DataFrame(data[:30])
df.columns=['User','exerciseType','rep_count','t (sec)','acc_x','acc_y','acc_z','gyro_x','gyro_y','gyro_z','magnet_x','magnet_y','magnet_z']
df['t (sec)']=df['t (sec)'].apply(lambda x: round(x,3))
df.head()
# Out:
#      User exerciseType  rep_count  t (sec)  acc_x  acc_y  acc_z  gyro_x  \
# 0  Morgan  bicep curls          0    0.000   0.00   0.00   0.00       0
# 1  Morgan  bicep curls          0    0.164  -0.04   0.90  -0.20     227
# 2  Morgan  bicep curls          0    0.243  -0.05   0.90  -0.22     425
# 3  Morgan  bicep curls          0    0.375  -0.08   0.90  -0.24    1485
# 4  Morgan  bicep curls          0    0.542  -0.10   0.89  -0.25    2026
#
#    gyro_y  gyro_z  magnet_x  magnet_y  magnet_z
# 0       0       0      0.00      0.00      0.00
# 1     281     -80     80.96   -201.48    224.48
# 2      -1    -443     80.04   -199.64    227.24
# 3    -190   -1723     88.32   -202.40    229.08
# 4    -799   -2590    103.96   -198.72    240.12
#
# [5 rows x 13 columns]

# %%
df.loc[1,'rep_count']=1

# %%
df.iloc[1]['t (sec)']
# Out:
# 0.16400000000000001

# %%
df[(df['t (sec)']>0.15-.05) & (df['t (sec)']<0.15+.05)].index.tolist()
# Out:
# [1]

# %%
df.head()
# Out:
#      User exerciseType  rep_count   t (sec)  acc_x  acc_y  acc_z  gyro_x  \
# 0  Morgan  bicep curls          0  0.000001   0.00   0.00   0.00       0
# 1  Morgan  bicep curls          1  0.164060  -0.04   0.90  -0.20     227
# 2  Morgan  bicep curls          0  0.242544  -0.05   0.90  -0.22     425
# 3  Morgan  bicep curls          0  0.374866  -0.08   0.90  -0.24    1485
# 4  Morgan  bicep curls          0  0.541655  -0.10   0.89  -0.25    2026
#
#    gyro_y  gyro_z  magnet_x  magnet_y  magnet_z
# 0       0       0      0.00      0.00      0.00
# 1     281     -80     80.96   -201.48    224.48
# 2      -1    -443     80.04   -199.64    227.24
# 3    -190   -1723     88.32   -202.40    229.08
# 4    -799   -2590    103.96   -198.72    240.12
#
# [5 rows x 13 columns]

# %%
def add_reps(mylist):
    global df
    count=0
    for indx in mylist:
        count+=1
        df.loc[indx,'rep_count']=count

# %%
df[df.set_id==1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-5e648fddc1cd> in <module>()
# ----> 1 df[df.set_id==1]
#
# /Users/Morgan/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1600             return self[name]
#    1601         raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1602                              (type(self).__name__, name))
#    1603
#    1604     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'set_id'

# %%
df.head()
# Out:
#      User exerciseType  rep_count  t (sec)  acc_x  acc_y  acc_z  gyro_x  \
# 0  Morgan  bicep curls          0    0.000   0.00   0.00   0.00       0
# 1  Morgan  bicep curls          1    0.164  -0.04   0.90  -0.20     227
# 2  Morgan  bicep curls          0    0.243  -0.05   0.90  -0.22     425
# 3  Morgan  bicep curls          0    0.375  -0.08   0.90  -0.24    1485
# 4  Morgan  bicep curls          0    0.542  -0.10   0.89  -0.25    2026
#
#    gyro_y  gyro_z  magnet_x  magnet_y  magnet_z
# 0       0       0      0.00      0.00      0.00
# 1     281     -80     80.96   -201.48    224.48
# 2      -1    -443     80.04   -199.64    227.24
# 3    -190   -1723     88.32   -202.40    229.08
# 4    -799   -2590    103.96   -198.72    240.12
#
# [5 rows x 13 columns]

# %%
with open ('all_samples.p','wb') as output_file:
    pickle.dump(data,output_file)
